# %%
# Dependencies
import tweepy
import json
from config import consumer_key, consumer_secret, access_token, access_token_secret

# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
# Search Term
search_term = input("Which term would you like to search for? ")

# Search for all tweets
public_tweets = api.search(search_term)
public_tweets
# Out:
# Which term would you like to search for? data boot camp
# {'statuses': [{'created_at': 'Mon Oct 21 14:30:00 +0000 2019',
#    'id': 1186288532282699776,
#    'id_str': '1186288532282699776',
#    'text': "That's why it's so great to see this Trilogy Education-powered boot camp student hone his public speaking skills as… https://t.co/WAXv00tyFE",
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/WAXv00tyFE',
#       'expanded_url': 'https://twitter.com/i/web/status/1186288532282699776',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://www.linkedin.com/" rel="nofollow">LinkedIn</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1037688654251151366,
#     'id_str': '1037688654251151366',
#     'name': 'AmyCampbell',
#     'screen_name': 'Iamcampbell24',
#     'location': 'Cape Town, South Africa',
#     'description': 'Talent Scout (Marketing, Creative, Operations) @getsmarter @2UInc. \nI love to run and drink wine...often running towards wine. @UniversityofCapeTown(UCT) Alumni',
#     'url': 'https://t.co/Imv8r7zcF1',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/Imv8r7zcF1',
#         'expanded_url': 'http://getsmarter.com/career-advice/',
#         'display_url': 'getsmarter.com/career-advice/',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 20,
#     'friends_count': 111,
#     'listed_count': 0,
#     'created_at': 'Thu Sep 06 13:07:09 +0000 2018',
#     'favourites_count': 12,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 238,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1037689633784647681/YoqJl-mw_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1037689633784647681/YoqJl-mw_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1037688654251151366/1536240606',
#     'profile_link_color': '91D2FA',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Mon Oct 21 14:00:00 +0000 2019',
#    'id': 1186280982120288257,
#    'id_str': '1186280982120288257',
#    'text': 'Signed up for \nMicrosoft Certified: Azure Data Engineer Boot Camp - Thursday at #PASSsummit \n\n@sqlpass  @grrl_geek\n#Azure',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'PASSsummit', 'indices': [80, 91]},
#      {'text': 'Azure', 'indices': [115, 121]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'sqlpass',
#       'name': 'PASS',
#       'id': 14639667,
#       'id_str': '14639667',
#       'indices': [94, 102]},
#      {'screen_name': 'grrl_geek',
#       'name': 'Jes Borland',
#       'id': 16797810,
#       'id_str': '16797810',
#       'indices': [104, 114]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 807770275,
#     'id_str': '807770275',
#     'name': 'Taiob Ali',
#     'screen_name': 'SqlWorldWide',
#     'location': 'Boston, MA',
#     'description': 'Microsoft MVP - Data Platform | SQL &  MongoDB certified data Professional | Organizer of #SQLSat877 | Co-Organizer @NESQLServer | Ran 26.2 miles on Oct 2015.',
#     'url': 'https://t.co/tXGXBvyK8w',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/tXGXBvyK8w',
#         'expanded_url': 'http://SqlWorldWide.com',
#         'display_url': 'SqlWorldWide.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 629,
#     'friends_count': 171,
#     'listed_count': 29,
#     'created_at': 'Thu Sep 06 23:07:00 +0000 2012',
#     'favourites_count': 4801,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 7849,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/767896597145460736/94lPVMeh_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/767896597145460736/94lPVMeh_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/807770275/1522951937',
#     'profile_link_color': '1B95E0',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 4,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Mon Oct 21 13:39:28 +0000 2019',
#    'id': 1186275811478982657,
#    'id_str': '1186275811478982657',
#    'text': "Listening to @KleerMail's Lisa Couture talk about data-driven #marketing at @NEDMA's boot camp this morning... https://t.co/dWj63N095o",
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'marketing', 'indices': [62, 72]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'KleerMail',
#       'name': 'KleerMail',
#       'id': 360575358,
#       'id_str': '360575358',
#       'indices': [13, 23]},
#      {'screen_name': 'NEDMA',
#       'name': 'NEDMA',
#       'id': 37791652,
#       'id_str': '37791652',
#       'indices': [76, 82]}],
#     'urls': [],
#     'media': [{'id': 1186274945199935491,
#       'id_str': '1186274945199935491',
#       'indices': [111, 134],
#       'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1186274945199935491/pu/img/_lKAm95a1_IGQkOS.jpg',
#       'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1186274945199935491/pu/img/_lKAm95a1_IGQkOS.jpg',
#       'url': 'https://t.co/dWj63N095o',
#       'display_url': 'pic.twitter.com/dWj63N095o',
#       'expanded_url': 'https://twitter.com/thebobcargill/status/1186275811478982657/video/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'medium': {'w': 1200, 'h': 675, 'resize': 'fit'},
#        'small': {'w': 680, 'h': 383, 'resize': 'fit'},
#        'large': {'w': 1280, 'h': 720, 'resize': 'fit'}}}]},
#    'extended_entities': {'media': [{'id': 1186274945199935491,
#       'id_str': '1186274945199935491',
#       'indices': [111, 134],
#       'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1186274945199935491/pu/img/_lKAm95a1_IGQkOS.jpg',
#       'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1186274945199935491/pu/img/_lKAm95a1_IGQkOS.jpg',
#       'url': 'https://t.co/dWj63N095o',
#       'display_url': 'pic.twitter.com/dWj63N095o',
#       'expanded_url': 'https://twitter.com/thebobcargill/status/1186275811478982657/video/1',
#       'type': 'video',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'medium': {'w': 1200, 'h': 675, 'resize': 'fit'},
#        'small': {'w': 680, 'h': 383, 'resize': 'fit'},
#        'large': {'w': 1280, 'h': 720, 'resize': 'fit'}},
#       'video_info': {'aspect_ratio': [16, 9],
#        'duration_millis': 82297,
#        'variants': [{'bitrate': 256000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/ext_tw_video/1186274945199935491/pu/vid/480x270/a7HI8KLzYL9vsvsF.mp4?tag=10'},
#         {'content_type': 'application/x-mpegURL',
#          'url': 'https://video.twimg.com/ext_tw_video/1186274945199935491/pu/pl/YFfykk4YdqTluH4N.m3u8?tag=10'},
#         {'bitrate': 2176000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/ext_tw_video/1186274945199935491/pu/vid/1280x720/FjlrHiZYAbd1mbGt.mp4?tag=10'},
#         {'bitrate': 832000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/ext_tw_video/1186274945199935491/pu/vid/640x360/fZaAeUeMllx2t18y.mp4?tag=10'}]},
#       'additional_media_info': {'monetizable': False}}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 14701398,
#     'id_str': '14701398',
#     'name': 'Bob Cargill',
#     'screen_name': 'thebobcargill',
#     'location': 'Sudbury, Massachusetts',
#     'description': "Copywriter, social media marketer, content creator, consultant, public speaker, past president of @NEDMA '99-'00 and current president of @amaBoston '18-'19.",
#     'url': 'https://t.co/QuzoKNirdR',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/QuzoKNirdR',
#         'expanded_url': 'https://thebobcargill.com',
#         'display_url': 'thebobcargill.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 5320,
#     'friends_count': 5332,
#     'listed_count': 585,
#     'created_at': 'Thu May 08 15:17:46 +0000 2008',
#     'favourites_count': 6561,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 29066,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '0099B9',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme4/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme4/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/867015981205467137/Kpac852m_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/867015981205467137/Kpac852m_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/14701398/1562944415',
#     'profile_link_color': '1B95E0',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': '95E8EC',
#     'profile_text_color': '3C3940',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': {'id': '39ad4ce00a983b1c',
#     'url': 'https://api.twitter.com/1.1/geo/id/39ad4ce00a983b1c.json',
#     'place_type': 'city',
#     'name': 'Burlington',
#     'full_name': 'Burlington, MA',
#     'country_code': 'US',
#     'country': 'United States',
#     'contained_within': [],
#     'bounding_box': {'type': 'Polygon',
#      'coordinates': [[[-71.240602, 42.46624],
#        [-71.16858, 42.46624],
#        [-71.16858, 42.544829],
#        [-71.240602, 42.544829]]]},
#     'attributes': {}},
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Mon Oct 21 13:38:40 +0000 2019',
#    'id': 1186275610877775873,
#    'id_str': '1186275610877775873',
#    'text': 'Cathy Horwitz is going to host a webinar on "3 Hour Excel Automation Boot Camp: Demystifying the Sort and Filter To… https://t.co/11Bpxbzt72',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/11Bpxbzt72',
#       'expanded_url': 'https://twitter.com/i/web/status/1186275610877775873',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1156269772180299776,
#     'id_str': '1156269772180299776',
#     'name': 'Global Wizdom',
#     'screen_name': 'GlobalWizdom',
#     'location': 'Colorado',
#     'description': 'We at Global Wizdom strive to deliver the best in class #Webinars, #OnlineTraining, & Onsite/In-Person #Training that meet your expectations. #GlobalWizdom',
#     'url': 'https://t.co/jTmzdCWtol',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/jTmzdCWtol',
#         'expanded_url': 'https://globalwizdom.com/',
#         'display_url': 'globalwizdom.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 2,
#     'friends_count': 0,
#     'listed_count': 0,
#     'created_at': 'Tue Jul 30 18:26:10 +0000 2019',
#     'favourites_count': 0,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 16,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1156304603916320768/GsPhGFWd_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1156304603916320768/GsPhGFWd_normal.png',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1156269772180299776/1564519476',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Mon Oct 21 13:31:55 +0000 2019',
#    'id': 1186273912872718336,
#    'id_str': '1186273912872718336',
#    'text': "Here's @KleerMail's Head of Client Relationships, Lisa Couture, and Marketing Manager, Ethan Bukowiec, talking abou… https://t.co/tzVKNpnIW1",
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'KleerMail',
#       'name': 'KleerMail',
#       'id': 360575358,
#       'id_str': '360575358',
#       'indices': [7, 17]}],
#     'urls': [{'url': 'https://t.co/tzVKNpnIW1',
#       'expanded_url': 'https://twitter.com/i/web/status/1186273912872718336',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 14701398,
#     'id_str': '14701398',
#     'name': 'Bob Cargill',
#     'screen_name': 'thebobcargill',
#     'location': 'Sudbury, Massachusetts',
#     'description': "Copywriter, social media marketer, content creator, consultant, public speaker, past president of @NEDMA '99-'00 and current president of @amaBoston '18-'19.",
#     'url': 'https://t.co/QuzoKNirdR',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/QuzoKNirdR',
#         'expanded_url': 'https://thebobcargill.com',
#         'display_url': 'thebobcargill.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 5320,
#     'friends_count': 5332,
#     'listed_count': 585,
#     'created_at': 'Thu May 08 15:17:46 +0000 2008',
#     'favourites_count': 6561,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 29066,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '0099B9',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme4/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme4/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/867015981205467137/Kpac852m_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/867015981205467137/Kpac852m_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/14701398/1562944415',
#     'profile_link_color': '1B95E0',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': '95E8EC',
#     'profile_text_color': '3C3940',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': {'id': '39ad4ce00a983b1c',
#     'url': 'https://api.twitter.com/1.1/geo/id/39ad4ce00a983b1c.json',
#     'place_type': 'city',
#     'name': 'Burlington',
#     'full_name': 'Burlington, MA',
#     'country_code': 'US',
#     'country': 'United States',
#     'contained_within': [],
#     'bounding_box': {'type': 'Polygon',
#      'coordinates': [[[-71.240602, 42.46624],
#        [-71.16858, 42.46624],
#        [-71.16858, 42.544829],
#        [-71.240602, 42.544829]]]},
#     'attributes': {}},
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Mon Oct 21 13:30:01 +0000 2019',
#    'id': 1186273434768199680,
#    'id_str': '1186273434768199680',
#    'text': "Soft skills are just as critical as hard skills. That's why it's great to see this Trilogy Education-powered boot c… https://t.co/NKCAADDa9v",
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/NKCAADDa9v',
#       'expanded_url': 'https://twitter.com/i/web/status/1186273434768199680',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://www.linkedin.com/" rel="nofollow">LinkedIn</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 271099601,
#     'id_str': '271099601',
#     'name': 'Rani Hammond',
#     'screen_name': 'ranigilani',
#     'location': 'Washington, DC',
#     'description': 'Passionately building Talent Capability and Capacity within Global Organizations with C-suite Executives.  Am an Aussie ex-pat that loves sun, surf and life!',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 289,
#     'friends_count': 452,
#     'listed_count': 12,
#     'created_at': 'Wed Mar 23 21:21:02 +0000 2011',
#     'favourites_count': 392,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 3962,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '0099B9',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme4/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme4/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/629286701324742656/mDHPvM-G_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/629286701324742656/mDHPvM-G_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/271099601/1513891020',
#     'profile_link_color': '3B94D9',
#     'profile_sidebar_border_color': '5ED4DC',
#     'profile_sidebar_fill_color': '95E8EC',
#     'profile_text_color': '3C3940',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 3,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Mon Oct 21 12:41:41 +0000 2019',
#    'id': 1186261271982854144,
#    'id_str': '1186261271982854144',
#    'text': '@PS4Ron @Sparrow0238 @mwthrowawayacc @VirusSnaps Only thing on the disc is the boot camp data , everything else is… https://t.co/eMLS3wwsjU',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'PS4Ron',
#       'name': 'Ron',
#       'id': 4494110603,
#       'id_str': '4494110603',
#       'indices': [0, 7]},
#      {'screen_name': 'Sparrow0238',
#       'name': '🎃Spooky Sparrow🎃',
#       'id': 4698228330,
#       'id_str': '4698228330',
#       'indices': [8, 20]},
#      {'screen_name': 'mwthrowawayacc',
#       'name': 'MW',
#       'id': 1185375480339296256,
#       'id_str': '1185375480339296256',
#       'indices': [21, 36]},
#      {'screen_name': 'VirusSnaps',
#       'name': 'Daniel Melendez IV',
#       'id': 2920854402,
#       'id_str': '2920854402',
#       'indices': [37, 48]}],
#     'urls': [{'url': 'https://t.co/eMLS3wwsjU',
#       'expanded_url': 'https://twitter.com/i/web/status/1186261271982854144',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [116, 139]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': 1186260891911753728,
#    'in_reply_to_status_id_str': '1186260891911753728',
#    'in_reply_to_user_id': 1022250332225716225,
#    'in_reply_to_user_id_str': '1022250332225716225',
#    'in_reply_to_screen_name': 'Morfid_plays',
#    'user': {'id': 1022250332225716225,
#     'id_str': '1022250332225716225',
#     'name': 'morfid_scares💀',
#     'screen_name': 'Morfid_plays',
#     'location': 'London',
#     'description': 'Artist for @switchplayermag and contributor for @theswitchisland . all opinions are my own. PlayStation - switch - physical media',
#     'url': 'https://t.co/3FtAJdcmJb',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/3FtAJdcmJb',
#         'expanded_url': 'http://www.instagram.com/morfid_plays',
#         'display_url': 'instagram.com/morfid_plays',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 278,
#     'friends_count': 815,
#     'listed_count': 4,
#     'created_at': 'Wed Jul 25 22:40:46 +0000 2018',
#     'favourites_count': 4894,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 6172,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1173739513929261056/cRlMHjuH_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1173739513929261056/cRlMHjuH_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1022250332225716225/1568121554',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sun Oct 20 10:00:55 +0000 2019',
#    'id': 1185858424157999104,
#    'id_str': '1185858424157999104',
#    'text': 'From personal data to immigration, find out how Brexit is going to affect your business by registering for a free B… https://t.co/yHgjA6f1dz',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/yHgjA6f1dz',
#       'expanded_url': 'https://twitter.com/i/web/status/1185858424157999104',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://www.hootsuite.com" rel="nofollow">Hootsuite Inc.</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 53352820,
#     'id_str': '53352820',
#     'name': 'Crawley Council',
#     'screen_name': 'crawleybc',
#     'location': 'Crawley, United Kingdom',
#     'description': 'Call 01293 438000, email comments@crawley.gov.uk or go online: https://t.co/adhjQ2YULT https://t.co/hrv43HzIww https://t.co/6dU8NaAc0W',
#     'url': 'https://t.co/adhjQ2YULT',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/adhjQ2YULT',
#         'expanded_url': 'http://www.crawley.gov.uk',
#         'display_url': 'crawley.gov.uk',
#         'indices': [0, 23]}]},
#      'description': {'urls': [{'url': 'https://t.co/adhjQ2YULT',
#         'expanded_url': 'http://www.crawley.gov.uk',
#         'display_url': 'crawley.gov.uk',
#         'indices': [63, 86]},
#        {'url': 'https://t.co/hrv43HzIww',
#         'expanded_url': 'http://www.facebook.com/crawleycouncil',
#         'display_url': 'facebook.com/crawleycouncil',
#         'indices': [87, 110]},
#        {'url': 'https://t.co/6dU8NaAc0W',
#         'expanded_url': 'http://www.instagram.com/crawleybc',
#         'display_url': 'instagram.com/crawleybc',
#         'indices': [111, 134]}]}},
#     'protected': False,
#     'followers_count': 7471,
#     'friends_count': 300,
#     'listed_count': 193,
#     'created_at': 'Fri Jul 03 10:39:20 +0000 2009',
#     'favourites_count': 424,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 11626,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'E4E5E7',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme5/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme5/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/982293117251604480/_oCpXMsQ_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/982293117251604480/_oCpXMsQ_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/53352820/1559563076',
#     'profile_link_color': 'E81C4F',
#     'profile_sidebar_border_color': '829D5E',
#     'profile_sidebar_fill_color': '99CC33',
#     'profile_text_color': '3E4415',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Sat Oct 19 13:19:00 +0000 2019',
#    'id': 1185545885616197633,
#    'id_str': '1185545885616197633',
#    'text': "We were in Bangalore for a data boot camp in 2016, and had the amazing @kiranshaw supporting us! We're back with ye… https://t.co/RPBsS6Wvog",
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'kiranshaw',
#       'name': 'Kiran Mazumdar Shaw',
#       'id': 145607857,
#       'id_str': '145607857',
#       'indices': [71, 81]}],
#     'urls': [{'url': 'https://t.co/RPBsS6Wvog',
#       'expanded_url': 'https://twitter.com/i/web/status/1185545885616197633',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 2957601684,
#     'id_str': '2957601684',
#     'name': 'Health Analytics Asia',
#     'screen_name': 'healthaasia',
#     'location': 'New Delhi, India',
#     'description': 'Data-driven platform to bring journalists,doctors,data scientists together to shape health reporting in Asia. A DataLEADS initiative awarded by @membershippzzle',
#     'url': 'https://t.co/6CyRWd6wwD',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/6CyRWd6wwD',
#         'expanded_url': 'http://ha-asia.com/',
#         'display_url': 'ha-asia.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1846,
#     'friends_count': 621,
#     'listed_count': 165,
#     'created_at': 'Sat Jan 03 19:51:11 +0000 2015',
#     'favourites_count': 2188,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 8489,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme18/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme18/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1135510577147551746/Xhxx3NCz_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1135510577147551746/Xhxx3NCz_normal.png',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2957601684/1559564061',
#     'profile_link_color': '89C9FA',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 9,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Fri Oct 18 20:17:39 +0000 2019',
#    'id': 1185288855622225921,
#    'id_str': '1185288855622225921',
#    'text': 'Interested in taking your #engineering career to the next level? Read how this process engineer gained an extra ski… https://t.co/A2qUyFycgB',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'engineering', 'indices': [26, 38]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/A2qUyFycgB',
#       'expanded_url': 'https://twitter.com/i/web/status/1185288855622225921',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 802566417560334340,
#     'id_str': '802566417560334340',
#     'name': 'Trilogy Education',
#     'screen_name': 'Trilogyedu',
#     'location': 'New York, USA',
#     'description': "Trilogy Education, a @2Uinc brand, empowers the world's leading universities to prepare professionals for high-growth careers in the digital economy.",
#     'url': 'https://t.co/r6j3jpkYeH',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/r6j3jpkYeH',
#         'expanded_url': 'http://www.trilogyed.com',
#         'display_url': 'trilogyed.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1438,
#     'friends_count': 262,
#     'listed_count': 22,
#     'created_at': 'Sat Nov 26 17:35:19 +0000 2016',
#     'favourites_count': 451,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 437,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/978374211801665538/Scj1ltjx_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/978374211801665538/Scj1ltjx_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/802566417560334340/1522098086',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 5,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Fri Oct 18 17:25:10 +0000 2019',
#    'id': 1185245450841907200,
#    'id_str': '1185245450841907200',
#    'text': '@benbbaldwin I don\'t know what the "most efficient" way is but I know that $15K for a boot camp isn\'t it. Come to U… https://t.co/5TmyAjl3nI',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'benbbaldwin',
#       'name': 'new-age analytical',
#       'id': 3030511365,
#       'id_str': '3030511365',
#       'indices': [0, 12]}],
#     'urls': [{'url': 'https://t.co/5TmyAjl3nI',
#       'expanded_url': 'https://twitter.com/i/web/status/1185245450841907200',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': 1185215196249444362,
#    'in_reply_to_status_id_str': '1185215196249444362',
#    'in_reply_to_user_id': 3030511365,
#    'in_reply_to_user_id_str': '3030511365',
#    'in_reply_to_screen_name': 'benbbaldwin',
#    'user': {'id': 107404271,
#     'id_str': '107404271',
#     'name': 'Ray R.',
#     'screen_name': 'ASURay81',
#     'location': 'Lincoln, NE',
#     'description': 'Sports enthusiast, political junkie, and data nerd.',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 83,
#     'friends_count': 294,
#     'listed_count': 4,
#     'created_at': 'Fri Jan 22 13:02:09 +0000 2010',
#     'favourites_count': 634,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 15225,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/833673191314698240/YJi8qfOX_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/833673191314698240/YJi8qfOX_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/107404271/1473657017',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Fri Oct 18 16:43:18 +0000 2019',
#    'id': 1185234914603487232,
#    'id_str': '1185234914603487232',
#    'text': '@wilreynolds Udemy is how I learned. Ultimate SQL boot camp had the clean data sets you need to do the work. IMO, H… https://t.co/3zUOqBosMj',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'wilreynolds',
#       'name': 'Wil Reynolds',
#       'id': 14178641,
#       'id_str': '14178641',
#       'indices': [0, 12]}],
#     'urls': [{'url': 'https://t.co/3zUOqBosMj',
#       'expanded_url': 'https://twitter.com/i/web/status/1185234914603487232',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': 1185176834524274689,
#    'in_reply_to_status_id_str': '1185176834524274689',
#    'in_reply_to_user_id': 14178641,
#    'in_reply_to_user_id_str': '14178641',
#    'in_reply_to_screen_name': 'wilreynolds',
#    'user': {'id': 814090,
#     'id_str': '814090',
#     'name': 'Morgan Brown',
#     'screen_name': 'morganb',
#     'location': 'Orange County, CA',
#     'description': "Author of 'Hacking Growth' from @crownpublishing. Product Manager @facebook. Proud Dad, married to @erikab.",
#     'url': 'https://t.co/5FyMgGpzxP',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/5FyMgGpzxP',
#         'expanded_url': 'https://www.amazon.com/Hacking-Growth-Fastest-Growing-Companies-Breakout/dp/045149721X/',
#         'display_url': 'amazon.com/Hacking-Growth…',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 32593,
#     'friends_count': 688,
#     'listed_count': 1538,
#     'created_at': 'Tue Mar 06 04:30:55 +0000 2007',
#     'favourites_count': 11025,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 31826,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '666666',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/809859076112797698/ASy-J7kI_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/809859076112797698/ASy-J7kI_normal.jpg',
#     'profile_link_color': '444446',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '949494',
#     'profile_text_color': '000000',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 3,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Fri Oct 18 16:14:39 +0000 2019',
#    'id': 1185227701373886465,
#    'id_str': '1185227701373886465',
#    'text': '@mixedknuts I just completed a data analytics boot camp from GW. Expensive, yes, but it did help me get a new job and a substantial raise.',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'mixedknuts',
#       'name': 'Ted Knutson',
#       'id': 136201836,
#       'id_str': '136201836',
#       'indices': [0, 11]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': 1185223574262616065,
#    'in_reply_to_status_id_str': '1185223574262616065',
#    'in_reply_to_user_id': 136201836,
#    'in_reply_to_user_id_str': '136201836',
#    'in_reply_to_screen_name': 'mixedknuts',
#    'user': {'id': 923169742495641605,
#     'id_str': '923169742495641605',
#     'name': 'Billy M',
#     'screen_name': 'Wideoverload',
#     'location': 'District of Columbia, USA',
#     'description': "Naglesmann's alter ego. Data Learner 📊. Comp and gif maker sometimes",
#     'url': 'https://t.co/IbgnunRIkP',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/IbgnunRIkP',
#         'expanded_url': 'https://www.youtube.com/channel/UCr8zoysxcpKwtl94PcC9d6Q/videos',
#         'display_url': 'youtube.com/channel/UCr8zo…',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 2251,
#     'friends_count': 267,
#     'listed_count': 39,
#     'created_at': 'Wed Oct 25 12:49:53 +0000 2017',
#     'favourites_count': 388,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 9167,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1151477928867389440/SAj1AOV6_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1151477928867389440/SAj1AOV6_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/923169742495641605/1550547648',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Fri Oct 18 16:01:51 +0000 2019',
#    'id': 1185224480953634818,
#    'id_str': '1185224480953634818',
#    'text': 'RT @beniaminoblanco: @benbbaldwin For someone interested in learning data analytics for decision making (sports, business, etc.) can you re…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'beniaminoblanco',
#       'name': 'Beniamino Blanco',
#       'id': 41012802,
#       'id_str': '41012802',
#       'indices': [3, 19]},
#      {'screen_name': 'benbbaldwin',
#       'name': 'new-age analytical',
#       'id': 3030511365,
#       'id_str': '3030511365',
#       'indices': [21, 33]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1098272487794753536,
#     'id_str': '1098272487794753536',
#     'name': 'vhsprime',
#     'screen_name': 'vhsprime',
#     'location': '',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 6,
#     'friends_count': 303,
#     'listed_count': 0,
#     'created_at': 'Wed Feb 20 17:25:40 +0000 2019',
#     'favourites_count': 3175,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 963,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#     'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': True,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Fri Oct 18 15:17:32 +0000 2019',
#     'id': 1185213329444425730,
#     'id_str': '1185213329444425730',
#     'text': '@benbbaldwin For someone interested in learning data analytics for decision making (sports, business, etc.) can you… https://t.co/ABNcYv0o8C',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'benbbaldwin',
#        'name': 'new-age analytical',
#        'id': 3030511365,
#        'id_str': '3030511365',
#        'indices': [0, 12]}],
#      'urls': [{'url': 'https://t.co/ABNcYv0o8C',
#        'expanded_url': 'https://twitter.com/i/web/status/1185213329444425730',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': 3030511365,
#     'in_reply_to_user_id_str': '3030511365',
#     'in_reply_to_screen_name': 'benbbaldwin',
#     'user': {'id': 41012802,
#      'id_str': '41012802',
#      'name': 'Beniamino Blanco',
#      'screen_name': 'beniaminoblanco',
#      'location': '',
#      'description': 'I rip and I rhyme\r\nI rhyme and I rip',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 28,
#      'friends_count': 452,
#      'listed_count': 1,
#      'created_at': 'Tue May 19 00:37:46 +0000 2009',
#      'favourites_count': 1276,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 520,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '022330',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme15/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme15/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1691872350/bx9DV_normal.gif',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1691872350/bx9DV_normal.gif',
#      'profile_link_color': '0084B4',
#      'profile_sidebar_border_color': 'A8C7F7',
#      'profile_sidebar_fill_color': 'C0DFEC',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 1,
#     'favorite_count': 24,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Fri Oct 18 15:30:15 +0000 2019',
#    'id': 1185216529190785026,
#    'id_str': '1185216529190785026',
#    'text': '@beniaminoblanco @benbbaldwin I work at a university, so let me give you my answer keeping that in mind\n\nI think th… https://t.co/7bNbQSmzFY',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'beniaminoblanco',
#       'name': 'Beniamino Blanco',
#       'id': 41012802,
#       'id_str': '41012802',
#       'indices': [0, 16]},
#      {'screen_name': 'benbbaldwin',
#       'name': 'new-age analytical',
#       'id': 3030511365,
#       'id_str': '3030511365',
#       'indices': [17, 29]}],
#     'urls': [{'url': 'https://t.co/7bNbQSmzFY',
#       'expanded_url': 'https://twitter.com/i/web/status/1185216529190785026',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#    'in_reply_to_status_id': 1185213329444425730,
#    'in_reply_to_status_id_str': '1185213329444425730',
#    'in_reply_to_user_id': 41012802,
#    'in_reply_to_user_id_str': '41012802',
#    'in_reply_to_screen_name': 'beniaminoblanco',
#    'user': {'id': 633176940,
#     'id_str': '633176940',
#     'name': 'YardsPerPass',
#     'screen_name': 'YardsPerPass',
#     'location': '1st and Goal @ the 3',
#     'description': "Bills stats & breakdowns.  Plus other football thoughts and views.\n\nGifs used according to the Copyright Act of 1976, 17 U.S.C. § 107\n\n**The people's tweeter**",
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 12784,
#     'friends_count': 265,
#     'listed_count': 230,
#     'created_at': 'Wed Jul 11 18:05:42 +0000 2012',
#     'favourites_count': 3558,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 44568,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/2388773347/baugh_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/2388773347/baugh_normal.jpg',
#     'profile_link_color': '91D2FA',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 3,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'}],
#  'search_metadata': {'completed_in': 0.043,
#   'max_id': 1186288532282699776,
#   'max_id_str': '1186288532282699776',
#   'next_results': '?max_id=1185216529190785025&q=data%20boot%20camp&include_entities=1',
#   'query': 'data+boot+camp',
#   'refresh_url': '?since_id=1186288532282699776&q=data%20boot%20camp&include_entities=1',
#   'count': 15,
#   'since_id': 0,
#   'since_id_str': '0'}}

# %%
# View Search Object
print(json.dumps(public_tweets, indent=4))

# Loop through all tweets
for tweet in public_tweets["statuses"]:

    # Utilize JSON dumps to generate a pretty-printed json
    # print(json.dumps(tweet, sort_keys=True, indent=4, separators=(',', ': ')))
    print(tweet["text"])
# Out:
# {
#     "statuses": [
#         {
#             "created_at": "Mon Oct 21 14:30:00 +0000 2019",
#             "id": 1186288532282699776,
#             "id_str": "1186288532282699776",
#             "text": "That's why it's so great to see this Trilogy Education-powered boot camp student hone his public speaking skills as\u2026 https://t.co/WAXv00tyFE",
#             "truncated": true,
#             "entities": {
#                 "hashtags": [],
#                 "symbols": [],
#                 "user_mentions": [],
#                 "urls": [
#                     {
#                         "url": "https://t.co/WAXv00tyFE",
#                         "expanded_url": "https://twitter.com/i/web/status/1186288532282699776",
#                         "display_url": "twitter.com/i/web/status/1\u2026",
#                         "indices": [
#                             117,
#                             140
#                         ]
#                     }
#                 ]
#             },
#             "metadata": {
#                 "iso_language_code": "en",
#                 "result_type": "recent"
#             },
#             "source": "<a href=\"http://www.linkedin.com/\" rel=\"nofollow\">LinkedIn</a>",
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "in_reply_to_screen_name": null,
#             "user": {
#                 "id": 1037688654251151366,
#                 "id_str": "1037688654251151366",
#                 "name": "AmyCampbell",
#                 "screen_name": "Iamcampbell24",
#                 "location": "Cape Town, South Africa",
#                 "description": "Talent Scout (Marketing, Creative, Operations) @getsmarter @2UInc. \nI love to run and drink wine...often running towards wine. @UniversityofCapeTown(UCT) Alumni",
#                 "url": "https://t.co/Imv8r7zcF1",
#                 "entities": {
#                     "url": {
#                         "urls": [
#                             {
#                                 "url": "https://t.co/Imv8r7zcF1",
#                                 "expanded_url": "http://getsmarter.com/career-advice/",
#                                 "display_url": "getsmarter.com/career-advice/",
#                                 "indices": [
#                                     0,
#                                     23
#                                 ]
#                             }
#                         ]
#                     },
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "protected": false,
#                 "followers_count": 20,
#                 "friends_count": 111,
#                 "listed_count": 0,
#                 "created_at": "Thu Sep 06 13:07:09 +0000 2018",
#                 "favourites_count": 12,
#                 "utc_offset": null,
#                 "time_zone": null,
#                 "geo_enabled": false,
#                 "verified": false,
#                 "statuses_count": 238,
#                 "lang": null,
#                 "contributors_enabled": false,
#                 "is_translator": false,
#                 "is_translation_enabled": false,
#                 "profile_background_color": "000000",
#                 "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#                 "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#                 "profile_background_tile": false,
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/1037689633784647681/YoqJl-mw_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/1037689633784647681/YoqJl-mw_normal.jpg",
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/1037688654251151366/1536240606",
#                 "profile_link_color": "91D2FA",
#                 "profile_sidebar_border_color": "000000",
#                 "profile_sidebar_fill_color": "000000",
#                 "profile_text_color": "000000",
#                 "profile_use_background_image": false,
#                 "has_extended_profile": true,
#                 "default_profile": false,
#                 "default_profile_image": false,
#                 "following": false,
#                 "follow_request_sent": false,
#                 "notifications": false,
#                 "translator_type": "none"
#             },
#             "geo": null,
#             "coordinates": null,
#             "place": null,
#             "contributors": null,
#             "is_quote_status": false,
#             "retweet_count": 0,
#             "favorite_count": 0,
#             "favorited": false,
#             "retweeted": false,
#             "possibly_sensitive": false,
#             "lang": "en"
#         },
#         {
#             "created_at": "Mon Oct 21 14:00:00 +0000 2019",
#             "id": 1186280982120288257,
#             "id_str": "1186280982120288257",
#             "text": "Signed up for \nMicrosoft Certified: Azure Data Engineer Boot Camp - Thursday at #PASSsummit \n\n@sqlpass  @grrl_geek\n#Azure",
#             "truncated": false,
#             "entities": {
#                 "hashtags": [
#                     {
#                         "text": "PASSsummit",
#                         "indices": [
#                             80,
#                             91
#                         ]
#                     },
#                     {
#                         "text": "Azure",
#                         "indices": [
#                             115,
#                             121
#                         ]
#                     }
#                 ],
#                 "symbols": [],
#                 "user_mentions": [
#                     {
#                         "screen_name": "sqlpass",
#                         "name": "PASS",
#                         "id": 14639667,
#                         "id_str": "14639667",
#                         "indices": [
#                             94,
#                             102
#                         ]
#                     },
#                     {
#                         "screen_name": "grrl_geek",
#                         "name": "Jes Borland",
#                         "id": 16797810,
#                         "id_str": "16797810",
#                         "indices": [
#                             104,
#                             114
#                         ]
#                     }
#                 ],
#                 "urls": []
#             },
#             "metadata": {
#                 "iso_language_code": "en",
#                 "result_type": "recent"
#             },
#             "source": "<a href=\"https://about.twitter.com/products/tweetdeck\" rel=\"nofollow\">TweetDeck</a>",
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "in_reply_to_screen_name": null,
#             "user": {
#                 "id": 807770275,
#                 "id_str": "807770275",
#                 "name": "Taiob Ali",
#                 "screen_name": "SqlWorldWide",
#                 "location": "Boston, MA",
#                 "description": "Microsoft MVP - Data Platform | SQL &  MongoDB certified data Professional | Organizer of #SQLSat877 | Co-Organizer @NESQLServer | Ran 26.2 miles on Oct 2015.",
#                 "url": "https://t.co/tXGXBvyK8w",
#                 "entities": {
#                     "url": {
#                         "urls": [
#                             {
#                                 "url": "https://t.co/tXGXBvyK8w",
#                                 "expanded_url": "http://SqlWorldWide.com",
#                                 "display_url": "SqlWorldWide.com",
#                                 "indices": [
#                                     0,
#                                     23
#                                 ]
#                             }
#                         ]
#                     },
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "protected": false,
#                 "followers_count": 629,
#                 "friends_count": 171,
#                 "listed_count": 29,
#                 "created_at": "Thu Sep 06 23:07:00 +0000 2012",
#                 "favourites_count": 4801,
#                 "utc_offset": null,
#                 "time_zone": null,
#                 "geo_enabled": false,
#                 "verified": false,
#                 "statuses_count": 7849,
#                 "lang": null,
#                 "contributors_enabled": false,
#                 "is_translator": false,
#                 "is_translation_enabled": false,
#                 "profile_background_color": "C0DEED",
#                 "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#                 "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#                 "profile_background_tile": false,
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/767896597145460736/94lPVMeh_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/767896597145460736/94lPVMeh_normal.jpg",
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/807770275/1522951937",
#                 "profile_link_color": "1B95E0",
#                 "profile_sidebar_border_color": "FFFFFF",
#                 "profile_sidebar_fill_color": "DDEEF6",
#                 "profile_text_color": "333333",
#                 "profile_use_background_image": true,
#                 "has_extended_profile": true,
#                 "default_profile": false,
#                 "default_profile_image": false,
#                 "following": false,
#                 "follow_request_sent": false,
#                 "notifications": false,
#                 "translator_type": "none"
#             },
#             "geo": null,
#             "coordinates": null,
#             "place": null,
#             "contributors": null,
#             "is_quote_status": false,
#             "retweet_count": 0,
#             "favorite_count": 4,
#             "favorited": false,
#             "retweeted": false,
#             "lang": "en"
#         },
#         {
#             "created_at": "Mon Oct 21 13:39:28 +0000 2019",
#             "id": 1186275811478982657,
#             "id_str": "1186275811478982657",
#             "text": "Listening to @KleerMail's Lisa Couture talk about data-driven #marketing at @NEDMA's boot camp this morning... https://t.co/dWj63N095o",
#             "truncated": false,
#             "entities": {
#                 "hashtags": [
#                     {
#                         "text": "marketing",
#                         "indices": [
#                             62,
#                             72
#                         ]
#                     }
#                 ],
#                 "symbols": [],
#                 "user_mentions": [
#                     {
#                         "screen_name": "KleerMail",
#                         "name": "KleerMail",
#                         "id": 360575358,
#                         "id_str": "360575358",
#                         "indices": [
#                             13,
#                             23
#                         ]
#                     },
#                     {
#                         "screen_name": "NEDMA",
#                         "name": "NEDMA",
#                         "id": 37791652,
#                         "id_str": "37791652",
#                         "indices": [
#                             76,
#                             82
#                         ]
#                     }
#                 ],
#                 "urls": [],
#                 "media": [
#                     {
#                         "id": 1186274945199935491,
#                         "id_str": "1186274945199935491",
#                         "indices": [
#                             111,
#                             134
#                         ],
#                         "media_url": "http://pbs.twimg.com/ext_tw_video_thumb/1186274945199935491/pu/img/_lKAm95a1_IGQkOS.jpg",
#                         "media_url_https": "https://pbs.twimg.com/ext_tw_video_thumb/1186274945199935491/pu/img/_lKAm95a1_IGQkOS.jpg",
#                         "url": "https://t.co/dWj63N095o",
#                         "display_url": "pic.twitter.com/dWj63N095o",
#                         "expanded_url": "https://twitter.com/thebobcargill/status/1186275811478982657/video/1",
#                         "type": "photo",
#                         "sizes": {
#                             "thumb": {
#                                 "w": 150,
#                                 "h": 150,
#                                 "resize": "crop"
#                             },
#                             "medium": {
#                                 "w": 1200,
#                                 "h": 675,
#                                 "resize": "fit"
#                             },
#                             "small": {
#                                 "w": 680,
#                                 "h": 383,
#                                 "resize": "fit"
#                             },
#                             "large": {
#                                 "w": 1280,
#                                 "h": 720,
#                                 "resize": "fit"
#                             }
#                         }
#                     }
#                 ]
#             },
#             "extended_entities": {
#                 "media": [
#                     {
#                         "id": 1186274945199935491,
#                         "id_str": "1186274945199935491",
#                         "indices": [
#                             111,
#                             134
#                         ],
#                         "media_url": "http://pbs.twimg.com/ext_tw_video_thumb/1186274945199935491/pu/img/_lKAm95a1_IGQkOS.jpg",
#                         "media_url_https": "https://pbs.twimg.com/ext_tw_video_thumb/1186274945199935491/pu/img/_lKAm95a1_IGQkOS.jpg",
#                         "url": "https://t.co/dWj63N095o",
#                         "display_url": "pic.twitter.com/dWj63N095o",
#                         "expanded_url": "https://twitter.com/thebobcargill/status/1186275811478982657/video/1",
#                         "type": "video",
#                         "sizes": {
#                             "thumb": {
#                                 "w": 150,
#                                 "h": 150,
#                                 "resize": "crop"
#                             },
#                             "medium": {
#                                 "w": 1200,
#                                 "h": 675,
#                                 "resize": "fit"
#                             },
#                             "small": {
#                                 "w": 680,
#                                 "h": 383,
#                                 "resize": "fit"
#                             },
#                             "large": {
#                                 "w": 1280,
#                                 "h": 720,
#                                 "resize": "fit"
#                             }
#                         },
#                         "video_info": {
#                             "aspect_ratio": [
#                                 16,
#                                 9
#                             ],
#                             "duration_millis": 82297,
#                             "variants": [
#                                 {
#                                     "bitrate": 256000,
#                                     "content_type": "video/mp4",
#                                     "url": "https://video.twimg.com/ext_tw_video/1186274945199935491/pu/vid/480x270/a7HI8KLzYL9vsvsF.mp4?tag=10"
#                                 },
#                                 {
#                                     "content_type": "application/x-mpegURL",
#                                     "url": "https://video.twimg.com/ext_tw_video/1186274945199935491/pu/pl/YFfykk4YdqTluH4N.m3u8?tag=10"
#                                 },
#                                 {
#                                     "bitrate": 2176000,
#                                     "content_type": "video/mp4",
#                                     "url": "https://video.twimg.com/ext_tw_video/1186274945199935491/pu/vid/1280x720/FjlrHiZYAbd1mbGt.mp4?tag=10"
#                                 },
#                                 {
#                                     "bitrate": 832000,
#                                     "content_type": "video/mp4",
#                                     "url": "https://video.twimg.com/ext_tw_video/1186274945199935491/pu/vid/640x360/fZaAeUeMllx2t18y.mp4?tag=10"
#                                 }
#                             ]
#                         },
#                         "additional_media_info": {
#                             "monetizable": false
#                         }
#                     }
#                 ]
#             },
#             "metadata": {
#                 "iso_language_code": "en",
#                 "result_type": "recent"
#             },
#             "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "in_reply_to_screen_name": null,
#             "user": {
#                 "id": 14701398,
#                 "id_str": "14701398",
#                 "name": "Bob Cargill",
#                 "screen_name": "thebobcargill",
#                 "location": "Sudbury, Massachusetts",
#                 "description": "Copywriter, social media marketer, content creator, consultant, public speaker, past president of @NEDMA '99-'00 and current president of @amaBoston '18-'19.",
#                 "url": "https://t.co/QuzoKNirdR",
#                 "entities": {
#                     "url": {
#                         "urls": [
#                             {
#                                 "url": "https://t.co/QuzoKNirdR",
#                                 "expanded_url": "https://thebobcargill.com",
#                                 "display_url": "thebobcargill.com",
#                                 "indices": [
#                                     0,
#                                     23
#                                 ]
#                             }
#                         ]
#                     },
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "protected": false,
#                 "followers_count": 5320,
#                 "friends_count": 5332,
#                 "listed_count": 585,
#                 "created_at": "Thu May 08 15:17:46 +0000 2008",
#                 "favourites_count": 6561,
#                 "utc_offset": null,
#                 "time_zone": null,
#                 "geo_enabled": true,
#                 "verified": false,
#                 "statuses_count": 29066,
#                 "lang": null,
#                 "contributors_enabled": false,
#                 "is_translator": false,
#                 "is_translation_enabled": false,
#                 "profile_background_color": "0099B9",
#                 "profile_background_image_url": "http://abs.twimg.com/images/themes/theme4/bg.gif",
#                 "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme4/bg.gif",
#                 "profile_background_tile": false,
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/867015981205467137/Kpac852m_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/867015981205467137/Kpac852m_normal.jpg",
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/14701398/1562944415",
#                 "profile_link_color": "1B95E0",
#                 "profile_sidebar_border_color": "FFFFFF",
#                 "profile_sidebar_fill_color": "95E8EC",
#                 "profile_text_color": "3C3940",
#                 "profile_use_background_image": true,
#                 "has_extended_profile": true,
#                 "default_profile": false,
#                 "default_profile_image": false,
#                 "following": false,
#                 "follow_request_sent": false,
#                 "notifications": false,
#                 "translator_type": "none"
#             },
#             "geo": null,
#             "coordinates": null,
#             "place": {
#                 "id": "39ad4ce00a983b1c",
#                 "url": "https://api.twitter.com/1.1/geo/id/39ad4ce00a983b1c.json",
#                 "place_type": "city",
#                 "name": "Burlington",
#                 "full_name": "Burlington, MA",
#                 "country_code": "US",
#                 "country": "United States",
#                 "contained_within": [],
#                 "bounding_box": {
#                     "type": "Polygon",
#                     "coordinates": [
#                         [
#                             [
#                                 -71.240602,
#                                 42.46624
#                             ],
#                             [
#                                 -71.16858,
#                                 42.46624
#                             ],
#                             [
#                                 -71.16858,
#                                 42.544829
#                             ],
#                             [
#                                 -71.240602,
#                                 42.544829
#                             ]
#                         ]
#                     ]
#                 },
#                 "attributes": {}
#             },
#             "contributors": null,
#             "is_quote_status": false,
#             "retweet_count": 0,
#             "favorite_count": 0,
#             "favorited": false,
#             "retweeted": false,
#             "possibly_sensitive": false,
#             "lang": "en"
#         },
#         {
#             "created_at": "Mon Oct 21 13:38:40 +0000 2019",
#             "id": 1186275610877775873,
#             "id_str": "1186275610877775873",
#             "text": "Cathy Horwitz is going to host a webinar on \"3 Hour Excel Automation Boot Camp: Demystifying the Sort and Filter To\u2026 https://t.co/11Bpxbzt72",
#             "truncated": true,
#             "entities": {
#                 "hashtags": [],
#                 "symbols": [],
#                 "user_mentions": [],
#                 "urls": [
#                     {
#                         "url": "https://t.co/11Bpxbzt72",
#                         "expanded_url": "https://twitter.com/i/web/status/1186275610877775873",
#                         "display_url": "twitter.com/i/web/status/1\u2026",
#                         "indices": [
#                             117,
#                             140
#                         ]
#                     }
#                 ]
#             },
#             "metadata": {
#                 "iso_language_code": "en",
#                 "result_type": "recent"
#             },
#             "source": "<a href=\"https://mobile.twitter.com\" rel=\"nofollow\">Twitter Web App</a>",
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "in_reply_to_screen_name": null,
#             "user": {
#                 "id": 1156269772180299776,
#                 "id_str": "1156269772180299776",
#                 "name": "Global Wizdom",
#                 "screen_name": "GlobalWizdom",
#                 "location": "Colorado",
#                 "description": "We at Global Wizdom strive to deliver the best in class #Webinars, #OnlineTraining, & Onsite/In-Person #Training that meet your expectations. #GlobalWizdom",
#                 "url": "https://t.co/jTmzdCWtol",
#                 "entities": {
#                     "url": {
#                         "urls": [
#                             {
#                                 "url": "https://t.co/jTmzdCWtol",
#                                 "expanded_url": "https://globalwizdom.com/",
#                                 "display_url": "globalwizdom.com",
#                                 "indices": [
#                                     0,
#                                     23
#                                 ]
#                             }
#                         ]
#                     },
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "protected": false,
#                 "followers_count": 2,
#                 "friends_count": 0,
#                 "listed_count": 0,
#                 "created_at": "Tue Jul 30 18:26:10 +0000 2019",
#                 "favourites_count": 0,
#                 "utc_offset": null,
#                 "time_zone": null,
#                 "geo_enabled": false,
#                 "verified": false,
#                 "statuses_count": 16,
#                 "lang": null,
#                 "contributors_enabled": false,
#                 "is_translator": false,
#                 "is_translation_enabled": false,
#                 "profile_background_color": "F5F8FA",
#                 "profile_background_image_url": null,
#                 "profile_background_image_url_https": null,
#                 "profile_background_tile": false,
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/1156304603916320768/GsPhGFWd_normal.png",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/1156304603916320768/GsPhGFWd_normal.png",
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/1156269772180299776/1564519476",
#                 "profile_link_color": "1DA1F2",
#                 "profile_sidebar_border_color": "C0DEED",
#                 "profile_sidebar_fill_color": "DDEEF6",
#                 "profile_text_color": "333333",
#                 "profile_use_background_image": true,
#                 "has_extended_profile": false,
#                 "default_profile": true,
#                 "default_profile_image": false,
#                 "following": false,
#                 "follow_request_sent": false,
#                 "notifications": false,
#                 "translator_type": "none"
#             },
#             "geo": null,
#             "coordinates": null,
#             "place": null,
#             "contributors": null,
#             "is_quote_status": false,
#             "retweet_count": 0,
#             "favorite_count": 0,
#             "favorited": false,
#             "retweeted": false,
#             "possibly_sensitive": false,
#             "lang": "en"
#         },
#         {
#             "created_at": "Mon Oct 21 13:31:55 +0000 2019",
#             "id": 1186273912872718336,
#             "id_str": "1186273912872718336",
#             "text": "Here's @KleerMail's Head of Client Relationships, Lisa Couture, and Marketing Manager, Ethan Bukowiec, talking abou\u2026 https://t.co/tzVKNpnIW1",
#             "truncated": true,
#             "entities": {
#                 "hashtags": [],
#                 "symbols": [],
#                 "user_mentions": [
#                     {
#                         "screen_name": "KleerMail",
#                         "name": "KleerMail",
#                         "id": 360575358,
#                         "id_str": "360575358",
#                         "indices": [
#                             7,
#                             17
#                         ]
#                     }
#                 ],
#                 "urls": [
#                     {
#                         "url": "https://t.co/tzVKNpnIW1",
#                         "expanded_url": "https://twitter.com/i/web/status/1186273912872718336",
#                         "display_url": "twitter.com/i/web/status/1\u2026",
#                         "indices": [
#                             117,
#                             140
#                         ]
#                     }
#                 ]
#             },
#             "metadata": {
#                 "iso_language_code": "en",
#                 "result_type": "recent"
#             },
#             "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "in_reply_to_screen_name": null,
#             "user": {
#                 "id": 14701398,
#                 "id_str": "14701398",
#                 "name": "Bob Cargill",
#                 "screen_name": "thebobcargill",
#                 "location": "Sudbury, Massachusetts",
#                 "description": "Copywriter, social media marketer, content creator, consultant, public speaker, past president of @NEDMA '99-'00 and current president of @amaBoston '18-'19.",
#                 "url": "https://t.co/QuzoKNirdR",
#                 "entities": {
#                     "url": {
#                         "urls": [
#                             {
#                                 "url": "https://t.co/QuzoKNirdR",
#                                 "expanded_url": "https://thebobcargill.com",
#                                 "display_url": "thebobcargill.com",
#                                 "indices": [
#                                     0,
#                                     23
#                                 ]
#                             }
#                         ]
#                     },
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "protected": false,
#                 "followers_count": 5320,
#                 "friends_count": 5332,
#                 "listed_count": 585,
#                 "created_at": "Thu May 08 15:17:46 +0000 2008",
#                 "favourites_count": 6561,
#                 "utc_offset": null,
#                 "time_zone": null,
#                 "geo_enabled": true,
#                 "verified": false,
#                 "statuses_count": 29066,
#                 "lang": null,
#                 "contributors_enabled": false,
#                 "is_translator": false,
#                 "is_translation_enabled": false,
#                 "profile_background_color": "0099B9",
#                 "profile_background_image_url": "http://abs.twimg.com/images/themes/theme4/bg.gif",
#                 "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme4/bg.gif",
#                 "profile_background_tile": false,
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/867015981205467137/Kpac852m_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/867015981205467137/Kpac852m_normal.jpg",
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/14701398/1562944415",
#                 "profile_link_color": "1B95E0",
#                 "profile_sidebar_border_color": "FFFFFF",
#                 "profile_sidebar_fill_color": "95E8EC",
#                 "profile_text_color": "3C3940",
#                 "profile_use_background_image": true,
#                 "has_extended_profile": true,
#                 "default_profile": false,
#                 "default_profile_image": false,
#                 "following": false,
#                 "follow_request_sent": false,
#                 "notifications": false,
#                 "translator_type": "none"
#             },
#             "geo": null,
#             "coordinates": null,
#             "place": {
#                 "id": "39ad4ce00a983b1c",
#                 "url": "https://api.twitter.com/1.1/geo/id/39ad4ce00a983b1c.json",
#                 "place_type": "city",
#                 "name": "Burlington",
#                 "full_name": "Burlington, MA",
#                 "country_code": "US",
#                 "country": "United States",
#                 "contained_within": [],
#                 "bounding_box": {
#                     "type": "Polygon",
#                     "coordinates": [
#                         [
#                             [
#                                 -71.240602,
#                                 42.46624
#                             ],
#                             [
#                                 -71.16858,
#                                 42.46624
#                             ],
#                             [
#                                 -71.16858,
#                                 42.544829
#                             ],
#                             [
#                                 -71.240602,
#                                 42.544829
#                             ]
#                         ]
#                     ]
#                 },
#                 "attributes": {}
#             },
#             "contributors": null,
#             "is_quote_status": false,
#             "retweet_count": 0,
#             "favorite_count": 0,
#             "favorited": false,
#             "retweeted": false,
#             "possibly_sensitive": false,
#             "lang": "en"
#         },
#         {
#             "created_at": "Mon Oct 21 13:30:01 +0000 2019",
#             "id": 1186273434768199680,
#             "id_str": "1186273434768199680",
#             "text": "Soft skills are just as critical as hard skills. That's why it's great to see this Trilogy Education-powered boot c\u2026 https://t.co/NKCAADDa9v",
#             "truncated": true,
#             "entities": {
#                 "hashtags": [],
#                 "symbols": [],
#                 "user_mentions": [],
#                 "urls": [
#                     {
#                         "url": "https://t.co/NKCAADDa9v",
#                         "expanded_url": "https://twitter.com/i/web/status/1186273434768199680",
#                         "display_url": "twitter.com/i/web/status/1\u2026",
#                         "indices": [
#                             117,
#                             140
#                         ]
#                     }
#                 ]
#             },
#             "metadata": {
#                 "iso_language_code": "en",
#                 "result_type": "recent"
#             },
#             "source": "<a href=\"http://www.linkedin.com/\" rel=\"nofollow\">LinkedIn</a>",
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "in_reply_to_screen_name": null,
#             "user": {
#                 "id": 271099601,
#                 "id_str": "271099601",
#                 "name": "Rani Hammond",
#                 "screen_name": "ranigilani",
#                 "location": "Washington, DC",
#                 "description": "Passionately building Talent Capability and Capacity within Global Organizations with C-suite Executives.  Am an Aussie ex-pat that loves sun, surf and life!",
#                 "url": null,
#                 "entities": {
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "protected": false,
#                 "followers_count": 289,
#                 "friends_count": 452,
#                 "listed_count": 12,
#                 "created_at": "Wed Mar 23 21:21:02 +0000 2011",
#                 "favourites_count": 392,
#                 "utc_offset": null,
#                 "time_zone": null,
#                 "geo_enabled": true,
#                 "verified": false,
#                 "statuses_count": 3962,
#                 "lang": null,
#                 "contributors_enabled": false,
#                 "is_translator": false,
#                 "is_translation_enabled": false,
#                 "profile_background_color": "0099B9",
#                 "profile_background_image_url": "http://abs.twimg.com/images/themes/theme4/bg.gif",
#                 "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme4/bg.gif",
#                 "profile_background_tile": false,
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/629286701324742656/mDHPvM-G_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/629286701324742656/mDHPvM-G_normal.jpg",
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/271099601/1513891020",
#                 "profile_link_color": "3B94D9",
#                 "profile_sidebar_border_color": "5ED4DC",
#                 "profile_sidebar_fill_color": "95E8EC",
#                 "profile_text_color": "3C3940",
#                 "profile_use_background_image": true,
#                 "has_extended_profile": false,
#                 "default_profile": false,
#                 "default_profile_image": false,
#                 "following": false,
#                 "follow_request_sent": false,
#                 "notifications": false,
#                 "translator_type": "none"
#             },
#             "geo": null,
#             "coordinates": null,
#             "place": null,
#             "contributors": null,
#             "is_quote_status": false,
#             "retweet_count": 0,
#             "favorite_count": 3,
#             "favorited": false,
#             "retweeted": false,
#             "possibly_sensitive": false,
#             "lang": "en"
#         },
#         {
#             "created_at": "Mon Oct 21 12:41:41 +0000 2019",
#             "id": 1186261271982854144,
#             "id_str": "1186261271982854144",
#             "text": "@PS4Ron @Sparrow0238 @mwthrowawayacc @VirusSnaps Only thing on the disc is the boot camp data , everything else is\u2026 https://t.co/eMLS3wwsjU",
#             "truncated": true,
#             "entities": {
#                 "hashtags": [],
#                 "symbols": [],
#                 "user_mentions": [
#                     {
#                         "screen_name": "PS4Ron",
#                         "name": "Ron",
#                         "id": 4494110603,
#                         "id_str": "4494110603",
#                         "indices": [
#                             0,
#                             7
#                         ]
#                     },
#                     {
#                         "screen_name": "Sparrow0238",
#                         "name": "\ud83c\udf83Spooky Sparrow\ud83c\udf83",
#                         "id": 4698228330,
#                         "id_str": "4698228330",
#                         "indices": [
#                             8,
#                             20
#                         ]
#                     },
#                     {
#                         "screen_name": "mwthrowawayacc",
#                         "name": "MW",
#                         "id": 1185375480339296256,
#                         "id_str": "1185375480339296256",
#                         "indices": [
#                             21,
#                             36
#                         ]
#                     },
#                     {
#                         "screen_name": "VirusSnaps",
#                         "name": "Daniel Melendez IV",
#                         "id": 2920854402,
#                         "id_str": "2920854402",
#                         "indices": [
#                             37,
#                             48
#                         ]
#                     }
#                 ],
#                 "urls": [
#                     {
#                         "url": "https://t.co/eMLS3wwsjU",
#                         "expanded_url": "https://twitter.com/i/web/status/1186261271982854144",
#                         "display_url": "twitter.com/i/web/status/1\u2026",
#                         "indices": [
#                             116,
#                             139
#                         ]
#                     }
#                 ]
#             },
#             "metadata": {
#                 "iso_language_code": "en",
#                 "result_type": "recent"
#             },
#             "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#             "in_reply_to_status_id": 1186260891911753728,
#             "in_reply_to_status_id_str": "1186260891911753728",
#             "in_reply_to_user_id": 1022250332225716225,
#             "in_reply_to_user_id_str": "1022250332225716225",
#             "in_reply_to_screen_name": "Morfid_plays",
#             "user": {
#                 "id": 1022250332225716225,
#                 "id_str": "1022250332225716225",
#                 "name": "morfid_scares\ud83d\udc80",
#                 "screen_name": "Morfid_plays",
#                 "location": "London",
#                 "description": "Artist for @switchplayermag and contributor for @theswitchisland . all opinions are my own. PlayStation - switch - physical media",
#                 "url": "https://t.co/3FtAJdcmJb",
#                 "entities": {
#                     "url": {
#                         "urls": [
#                             {
#                                 "url": "https://t.co/3FtAJdcmJb",
#                                 "expanded_url": "http://www.instagram.com/morfid_plays",
#                                 "display_url": "instagram.com/morfid_plays",
#                                 "indices": [
#                                     0,
#                                     23
#                                 ]
#                             }
#                         ]
#                     },
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "protected": false,
#                 "followers_count": 278,
#                 "friends_count": 815,
#                 "listed_count": 4,
#                 "created_at": "Wed Jul 25 22:40:46 +0000 2018",
#                 "favourites_count": 4894,
#                 "utc_offset": null,
#                 "time_zone": null,
#                 "geo_enabled": false,
#                 "verified": false,
#                 "statuses_count": 6172,
#                 "lang": null,
#                 "contributors_enabled": false,
#                 "is_translator": false,
#                 "is_translation_enabled": false,
#                 "profile_background_color": "F5F8FA",
#                 "profile_background_image_url": null,
#                 "profile_background_image_url_https": null,
#                 "profile_background_tile": false,
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/1173739513929261056/cRlMHjuH_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/1173739513929261056/cRlMHjuH_normal.jpg",
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/1022250332225716225/1568121554",
#                 "profile_link_color": "1DA1F2",
#                 "profile_sidebar_border_color": "C0DEED",
#                 "profile_sidebar_fill_color": "DDEEF6",
#                 "profile_text_color": "333333",
#                 "profile_use_background_image": true,
#                 "has_extended_profile": false,
#                 "default_profile": true,
#                 "default_profile_image": false,
#                 "following": false,
#                 "follow_request_sent": false,
#                 "notifications": false,
#                 "translator_type": "none"
#             },
#             "geo": null,
#             "coordinates": null,
#             "place": null,
#             "contributors": null,
#             "is_quote_status": false,
#             "retweet_count": 0,
#             "favorite_count": 0,
#             "favorited": false,
#             "retweeted": false,
#             "lang": "en"
#         },
#         {
#             "created_at": "Sun Oct 20 10:00:55 +0000 2019",
#             "id": 1185858424157999104,
#             "id_str": "1185858424157999104",
#             "text": "From personal data to immigration, find out how Brexit is going to affect your business by registering for a free B\u2026 https://t.co/yHgjA6f1dz",
#             "truncated": true,
#             "entities": {
#                 "hashtags": [],
#                 "symbols": [],
#                 "user_mentions": [],
#                 "urls": [
#                     {
#                         "url": "https://t.co/yHgjA6f1dz",
#                         "expanded_url": "https://twitter.com/i/web/status/1185858424157999104",
#                         "display_url": "twitter.com/i/web/status/1\u2026",
#                         "indices": [
#                             117,
#                             140
#                         ]
#                     }
#                 ]
#             },
#             "metadata": {
#                 "iso_language_code": "en",
#                 "result_type": "recent"
#             },
#             "source": "<a href=\"https://www.hootsuite.com\" rel=\"nofollow\">Hootsuite Inc.</a>",
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "in_reply_to_screen_name": null,
#             "user": {
#                 "id": 53352820,
#                 "id_str": "53352820",
#                 "name": "Crawley Council",
#                 "screen_name": "crawleybc",
#                 "location": "Crawley, United Kingdom",
#                 "description": "Call 01293 438000, email comments@crawley.gov.uk or go online: https://t.co/adhjQ2YULT https://t.co/hrv43HzIww https://t.co/6dU8NaAc0W",
#                 "url": "https://t.co/adhjQ2YULT",
#                 "entities": {
#                     "url": {
#                         "urls": [
#                             {
#                                 "url": "https://t.co/adhjQ2YULT",
#                                 "expanded_url": "http://www.crawley.gov.uk",
#                                 "display_url": "crawley.gov.uk",
#                                 "indices": [
#                                     0,
#                                     23
#                                 ]
#                             }
#                         ]
#                     },
#                     "description": {
#                         "urls": [
#                             {
#                                 "url": "https://t.co/adhjQ2YULT",
#                                 "expanded_url": "http://www.crawley.gov.uk",
#                                 "display_url": "crawley.gov.uk",
#                                 "indices": [
#                                     63,
#                                     86
#                                 ]
#                             },
#                             {
#                                 "url": "https://t.co/hrv43HzIww",
#                                 "expanded_url": "http://www.facebook.com/crawleycouncil",
#                                 "display_url": "facebook.com/crawleycouncil",
#                                 "indices": [
#                                     87,
#                                     110
#                                 ]
#                             },
#                             {
#                                 "url": "https://t.co/6dU8NaAc0W",
#                                 "expanded_url": "http://www.instagram.com/crawleybc",
#                                 "display_url": "instagram.com/crawleybc",
#                                 "indices": [
#                                     111,
#                                     134
#                                 ]
#                             }
#                         ]
#                     }
#                 },
#                 "protected": false,
#                 "followers_count": 7471,
#                 "friends_count": 300,
#                 "listed_count": 193,
#                 "created_at": "Fri Jul 03 10:39:20 +0000 2009",
#                 "favourites_count": 424,
#                 "utc_offset": null,
#                 "time_zone": null,
#                 "geo_enabled": false,
#                 "verified": false,
#                 "statuses_count": 11626,
#                 "lang": null,
#                 "contributors_enabled": false,
#                 "is_translator": false,
#                 "is_translation_enabled": false,
#                 "profile_background_color": "E4E5E7",
#                 "profile_background_image_url": "http://abs.twimg.com/images/themes/theme5/bg.gif",
# ...
#             "truncated": false,
#             "entities": {
#                 "hashtags": [],
#                 "symbols": [],
#                 "user_mentions": [
#                     {
#                         "screen_name": "beniaminoblanco",
#                         "name": "Beniamino Blanco",
#                         "id": 41012802,
#                         "id_str": "41012802",
#                         "indices": [
#                             3,
#                             19
#                         ]
#                     },
#                     {
#                         "screen_name": "benbbaldwin",
#                         "name": "new-age analytical",
#                         "id": 3030511365,
#                         "id_str": "3030511365",
#                         "indices": [
#                             21,
#                             33
#                         ]
#                     }
#                 ],
#                 "urls": []
#             },
#             "metadata": {
#                 "iso_language_code": "en",
#                 "result_type": "recent"
#             },
#             "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "in_reply_to_screen_name": null,
#             "user": {
#                 "id": 1098272487794753536,
#                 "id_str": "1098272487794753536",
#                 "name": "vhsprime",
#                 "screen_name": "vhsprime",
#                 "location": "",
#                 "description": "",
#                 "url": null,
#                 "entities": {
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "protected": false,
#                 "followers_count": 6,
#                 "friends_count": 303,
#                 "listed_count": 0,
#                 "created_at": "Wed Feb 20 17:25:40 +0000 2019",
#                 "favourites_count": 3175,
#                 "utc_offset": null,
#                 "time_zone": null,
#                 "geo_enabled": false,
#                 "verified": false,
#                 "statuses_count": 963,
#                 "lang": null,
#                 "contributors_enabled": false,
#                 "is_translator": false,
#                 "is_translation_enabled": false,
#                 "profile_background_color": "F5F8FA",
#                 "profile_background_image_url": null,
#                 "profile_background_image_url_https": null,
#                 "profile_background_tile": false,
#                 "profile_image_url": "http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png",
#                 "profile_image_url_https": "https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png",
#                 "profile_link_color": "1DA1F2",
#                 "profile_sidebar_border_color": "C0DEED",
#                 "profile_sidebar_fill_color": "DDEEF6",
#                 "profile_text_color": "333333",
#                 "profile_use_background_image": true,
#                 "has_extended_profile": false,
#                 "default_profile": true,
#                 "default_profile_image": true,
#                 "following": false,
#                 "follow_request_sent": false,
#                 "notifications": false,
#                 "translator_type": "none"
#             },
#             "geo": null,
#             "coordinates": null,
#             "place": null,
#             "contributors": null,
#             "retweeted_status": {
#                 "created_at": "Fri Oct 18 15:17:32 +0000 2019",
#                 "id": 1185213329444425730,
#                 "id_str": "1185213329444425730",
#                 "text": "@benbbaldwin For someone interested in learning data analytics for decision making (sports, business, etc.) can you\u2026 https://t.co/ABNcYv0o8C",
#                 "truncated": true,
#                 "entities": {
#                     "hashtags": [],
#                     "symbols": [],
#                     "user_mentions": [
#                         {
#                             "screen_name": "benbbaldwin",
#                             "name": "new-age analytical",
#                             "id": 3030511365,
#                             "id_str": "3030511365",
#                             "indices": [
#                                 0,
#                                 12
#                             ]
#                         }
#                     ],
#                     "urls": [
#                         {
#                             "url": "https://t.co/ABNcYv0o8C",
#                             "expanded_url": "https://twitter.com/i/web/status/1185213329444425730",
#                             "display_url": "twitter.com/i/web/status/1\u2026",
#                             "indices": [
#                                 117,
#                                 140
#                             ]
#                         }
#                     ]
#                 },
#                 "metadata": {
#                     "iso_language_code": "en",
#                     "result_type": "recent"
#                 },
#                 "source": "<a href=\"https://mobile.twitter.com\" rel=\"nofollow\">Twitter Web App</a>",
#                 "in_reply_to_status_id": null,
#                 "in_reply_to_status_id_str": null,
#                 "in_reply_to_user_id": 3030511365,
#                 "in_reply_to_user_id_str": "3030511365",
#                 "in_reply_to_screen_name": "benbbaldwin",
#                 "user": {
#                     "id": 41012802,
#                     "id_str": "41012802",
#                     "name": "Beniamino Blanco",
#                     "screen_name": "beniaminoblanco",
#                     "location": "",
#                     "description": "I rip and I rhyme\r\nI rhyme and I rip",
#                     "url": null,
#                     "entities": {
#                         "description": {
#                             "urls": []
#                         }
#                     },
#                     "protected": false,
#                     "followers_count": 28,
#                     "friends_count": 452,
#                     "listed_count": 1,
#                     "created_at": "Tue May 19 00:37:46 +0000 2009",
#                     "favourites_count": 1276,
#                     "utc_offset": null,
#                     "time_zone": null,
#                     "geo_enabled": false,
#                     "verified": false,
#                     "statuses_count": 520,
#                     "lang": null,
#                     "contributors_enabled": false,
#                     "is_translator": false,
#                     "is_translation_enabled": false,
#                     "profile_background_color": "022330",
#                     "profile_background_image_url": "http://abs.twimg.com/images/themes/theme15/bg.png",
#                     "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme15/bg.png",
#                     "profile_background_tile": false,
#                     "profile_image_url": "http://pbs.twimg.com/profile_images/1691872350/bx9DV_normal.gif",
#                     "profile_image_url_https": "https://pbs.twimg.com/profile_images/1691872350/bx9DV_normal.gif",
#                     "profile_link_color": "0084B4",
#                     "profile_sidebar_border_color": "A8C7F7",
#                     "profile_sidebar_fill_color": "C0DFEC",
#                     "profile_text_color": "333333",
#                     "profile_use_background_image": true,
#                     "has_extended_profile": false,
#                     "default_profile": false,
#                     "default_profile_image": false,
#                     "following": false,
#                     "follow_request_sent": false,
#                     "notifications": false,
#                     "translator_type": "none"
#                 },
#                 "geo": null,
#                 "coordinates": null,
#                 "place": null,
#                 "contributors": null,
#                 "is_quote_status": false,
#                 "retweet_count": 1,
#                 "favorite_count": 24,
#                 "favorited": false,
#                 "retweeted": false,
#                 "lang": "en"
#             },
#             "is_quote_status": false,
#             "retweet_count": 1,
#             "favorite_count": 0,
#             "favorited": false,
#             "retweeted": false,
#             "lang": "en"
#         },
#         {
#             "created_at": "Fri Oct 18 15:30:15 +0000 2019",
#             "id": 1185216529190785026,
#             "id_str": "1185216529190785026",
#             "text": "@beniaminoblanco @benbbaldwin I work at a university, so let me give you my answer keeping that in mind\n\nI think th\u2026 https://t.co/7bNbQSmzFY",
#             "truncated": true,
#             "entities": {
#                 "hashtags": [],
#                 "symbols": [],
#                 "user_mentions": [
#                     {
#                         "screen_name": "beniaminoblanco",
#                         "name": "Beniamino Blanco",
#                         "id": 41012802,
#                         "id_str": "41012802",
#                         "indices": [
#                             0,
#                             16
#                         ]
#                     },
#                     {
#                         "screen_name": "benbbaldwin",
#                         "name": "new-age analytical",
#                         "id": 3030511365,
#                         "id_str": "3030511365",
#                         "indices": [
#                             17,
#                             29
#                         ]
#                     }
#                 ],
#                 "urls": [
#                     {
#                         "url": "https://t.co/7bNbQSmzFY",
#                         "expanded_url": "https://twitter.com/i/web/status/1185216529190785026",
#                         "display_url": "twitter.com/i/web/status/1\u2026",
#                         "indices": [
#                             117,
#                             140
#                         ]
#                     }
#                 ]
#             },
#             "metadata": {
#                 "iso_language_code": "en",
#                 "result_type": "recent"
#             },
#             "source": "<a href=\"https://about.twitter.com/products/tweetdeck\" rel=\"nofollow\">TweetDeck</a>",
#             "in_reply_to_status_id": 1185213329444425730,
#             "in_reply_to_status_id_str": "1185213329444425730",
#             "in_reply_to_user_id": 41012802,
#             "in_reply_to_user_id_str": "41012802",
#             "in_reply_to_screen_name": "beniaminoblanco",
#             "user": {
#                 "id": 633176940,
#                 "id_str": "633176940",
#                 "name": "YardsPerPass",
#                 "screen_name": "YardsPerPass",
#                 "location": "1st and Goal @ the 3",
#                 "description": "Bills stats & breakdowns.  Plus other football thoughts and views.\n\nGifs used according to the Copyright Act of 1976, 17 U.S.C. \u00a7 107\n\n**The people's tweeter**",
#                 "url": null,
#                 "entities": {
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "protected": false,
#                 "followers_count": 12784,
#                 "friends_count": 265,
#                 "listed_count": 230,
#                 "created_at": "Wed Jul 11 18:05:42 +0000 2012",
#                 "favourites_count": 3558,
#                 "utc_offset": null,
#                 "time_zone": null,
#                 "geo_enabled": false,
#                 "verified": false,
#                 "statuses_count": 44568,
#                 "lang": null,
#                 "contributors_enabled": false,
#                 "is_translator": false,
#                 "is_translation_enabled": false,
#                 "profile_background_color": "000000",
#                 "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#                 "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#                 "profile_background_tile": false,
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/2388773347/baugh_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/2388773347/baugh_normal.jpg",
#                 "profile_link_color": "91D2FA",
#                 "profile_sidebar_border_color": "000000",
#                 "profile_sidebar_fill_color": "000000",
#                 "profile_text_color": "000000",
#                 "profile_use_background_image": false,
#                 "has_extended_profile": false,
#                 "default_profile": false,
#                 "default_profile_image": false,
#                 "following": false,
#                 "follow_request_sent": false,
#                 "notifications": false,
#                 "translator_type": "none"
#             },
#             "geo": null,
#             "coordinates": null,
#             "place": null,
#             "contributors": null,
#             "is_quote_status": false,
#             "retweet_count": 0,
#             "favorite_count": 3,
#             "favorited": false,
#             "retweeted": false,
#             "lang": "en"
#         }
#     ],
#     "search_metadata": {
#         "completed_in": 0.043,
#         "max_id": 1186288532282699776,
#         "max_id_str": "1186288532282699776",
#         "next_results": "?max_id=1185216529190785025&q=data%20boot%20camp&include_entities=1",
#         "query": "data+boot+camp",
#         "refresh_url": "?since_id=1186288532282699776&q=data%20boot%20camp&include_entities=1",
#         "count": 15,
#         "since_id": 0,
#         "since_id_str": "0"
#     }
# }
# That's why it's so great to see this Trilogy Education-powered boot camp student hone his public speaking skills as… https://t.co/WAXv00tyFE
# Signed up for
# Microsoft Certified: Azure Data Engineer Boot Camp - Thursday at #PASSsummit
#
# @sqlpass  @grrl_geek
# #Azure
# Listening to @KleerMail's Lisa Couture talk about data-driven #marketing at @NEDMA's boot camp this morning... https://t.co/dWj63N095o
# Cathy Horwitz is going to host a webinar on "3 Hour Excel Automation Boot Camp: Demystifying the Sort and Filter To… https://t.co/11Bpxbzt72
# Here's @KleerMail's Head of Client Relationships, Lisa Couture, and Marketing Manager, Ethan Bukowiec, talking abou… https://t.co/tzVKNpnIW1
# Soft skills are just as critical as hard skills. That's why it's great to see this Trilogy Education-powered boot c… https://t.co/NKCAADDa9v
# @PS4Ron @Sparrow0238 @mwthrowawayacc @VirusSnaps Only thing on the disc is the boot camp data , everything else is… https://t.co/eMLS3wwsjU
# From personal data to immigration, find out how Brexit is going to affect your business by registering for a free B… https://t.co/yHgjA6f1dz
# We were in Bangalore for a data boot camp in 2016, and had the amazing @kiranshaw supporting us! We're back with ye… https://t.co/RPBsS6Wvog
# Interested in taking your #engineering career to the next level? Read how this process engineer gained an extra ski… https://t.co/A2qUyFycgB
# @benbbaldwin I don't know what the "most efficient" way is but I know that $15K for a boot camp isn't it. Come to U… https://t.co/5TmyAjl3nI
# @wilreynolds Udemy is how I learned. Ultimate SQL boot camp had the clean data sets you need to do the work. IMO, H… https://t.co/3zUOqBosMj
# @mixedknuts I just completed a data analytics boot camp from GW. Expensive, yes, but it did help me get a new job and a substantial raise.
# RT @beniaminoblanco: @benbbaldwin For someone interested in learning data analytics for decision making (sports, business, etc.) can you re…
# @beniaminoblanco @benbbaldwin I work at a university, so let me give you my answer keeping that in mind
#
# I think th… https://t.co/7bNbQSmzFY
