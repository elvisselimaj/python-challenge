# %%
# %matplotlib notebook

# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ### Using MatplotLib to Chart a DataFrame

# %%
# Load in csv
rain_df = pd.read_csv("../Resources/avg_rain_state.csv")
rain_df.head()
# Out:
#         State  Inches  Milli­metres  Rank
# 0     Alabama    58.3          1480     4
# 1      Alaska    22.5           572    39
# 2     Arizona    13.6           345    47
# 3    Arkansas    50.6          1284     8
# 4  California    22.2           563    40

# %%
# Set x axis and tick locations
x_axis = np.arange(len(rain_df))
tick_locations = x_axis

# %%
# Create a list indicating where to write x labels and set figure size to adjust for space
plt.figure(figsize=(20,3))
plt.bar(x_axis, rain_df["Inches"], color='r', alpha=0.5, align="center")
plt.xticks(tick_locations, rain_df["State"], rotation="vertical")
# Out:
# <img src="data:image/png;base64,..." width="1666.6666666666667">
# ([<matplotlib.axis.XTick at 0x27dba2b45f8>,
#   <matplotlib.axis.XTick at 0x27dba299f28>,
#   <matplotlib.axis.XTick at 0x27dba299c88>,
#   <matplotlib.axis.XTick at 0x27dba3731d0>,
#   <matplotlib.axis.XTick at 0x27dba373630>,
#   <matplotlib.axis.XTick at 0x27dba373ba8>,
#   <matplotlib.axis.XTick at 0x27dba380198>,
#   <matplotlib.axis.XTick at 0x27dba3806d8>,
#   <matplotlib.axis.XTick at 0x27dba373208>,
#   <matplotlib.axis.XTick at 0x27dba380d68>,
#   <matplotlib.axis.XTick at 0x27dba387160>,
#   <matplotlib.axis.XTick at 0x27dba387668>,
#   <matplotlib.axis.XTick at 0x27dba387be0>,
#   <matplotlib.axis.XTick at 0x27dba38f198>,
#   <matplotlib.axis.XTick at 0x27dba38f710>,
#   <matplotlib.axis.XTick at 0x27dba38fc88>,
#   <matplotlib.axis.XTick at 0x27dba397240>,
#   <matplotlib.axis.XTick at 0x27dba38f240>,
#   <matplotlib.axis.XTick at 0x27dba387630>,
#   <matplotlib.axis.XTick at 0x27dba397a20>,
#   <matplotlib.axis.XTick at 0x27dba397da0>,
#   <matplotlib.axis.XTick at 0x27dba39e358>,
#   <matplotlib.axis.XTick at 0x27dba39e8d0>,
#   <matplotlib.axis.XTick at 0x27dba39ee48>,
#   <matplotlib.axis.XTick at 0x27dba3a4400>,
#   <matplotlib.axis.XTick at 0x27dba3a4978>,
#   <matplotlib.axis.XTick at 0x27dba3a4ef0>,
#   <matplotlib.axis.XTick at 0x27dba3a4a58>,
#   <matplotlib.axis.XTick at 0x27dba39e978>,
#   <matplotlib.axis.XTick at 0x27dba3ab3c8>,
#   <matplotlib.axis.XTick at 0x27dba3ab940>,
#   <matplotlib.axis.XTick at 0x27dba3abeb8>,
#   <matplotlib.axis.XTick at 0x27dba3b2470>,
#   <matplotlib.axis.XTick at 0x27dba3b29e8>,
#   <matplotlib.axis.XTick at 0x27dba3b2f60>,
#   <matplotlib.axis.XTick at 0x27dba3b8518>,
#   <matplotlib.axis.XTick at 0x27dba3b23c8>,
#   <matplotlib.axis.XTick at 0x27dba3ab7b8>,
#   <matplotlib.axis.XTick at 0x27dba3b86d8>,
#   <matplotlib.axis.XTick at 0x27dba3b8e80>,
#   <matplotlib.axis.XTick at 0x27dba3c0550>,
#   <matplotlib.axis.XTick at 0x27dba3c0ac8>,
#   <matplotlib.axis.XTick at 0x27dba3c70f0>,
#   <matplotlib.axis.XTick at 0x27dba3c75f8>,
#   <matplotlib.axis.XTick at 0x27dba3c7b70>,
#   <matplotlib.axis.XTick at 0x27dba3d0160>,
#   <matplotlib.axis.XTick at 0x27dba3c79e8>,
#   <matplotlib.axis.XTick at 0x27dba3b8da0>,
#   <matplotlib.axis.XTick at 0x27dba3d05c0>,
#   <matplotlib.axis.XTick at 0x27dba3d0b38>],
#  <a list of 50 Text xticklabel objects>)

# %%
# Set x and y limits
plt.xlim(-0.75, len(x_axis))
plt.ylim(0, max(rain_df["Inches"])+10)
# Out:
# (0, 73.7)

# %%
# Set a Title and labels
plt.title("Average Rain per State")
plt.xlabel("State")
plt.ylabel("Average Amount of Rainfall in Inches")
# Out:
# Text(33.74305555555555, 0.5, 'Average Amount of Rainfall in Inches')

# %%
# Save our graph and show the grap
plt.tight_layout()
plt.savefig("../Images/avg_state_rain.png")
plt.show()

# %% [markdown]
# ### Using Pandas to Chart a DataFrame

# %%
# Filter the DataFrame down only to those columns to chart
state_and_inches = rain_df[["State","Inches"]]

# Set the index to be "State" so they will be used as labels
state_and_inches = state_and_inches.set_index("State")

state_and_inches.head()
# Out:
#             Inches
# State
# Alabama       58.3
# Alaska        22.5
# Arizona       13.6
# Arkansas      50.6
# California    22.2

# %%
# Use DataFrame.plot() in order to create a bar chart of the data
state_and_inches.plot(kind="bar", figsize=(20,3))

# Set a title for the chart
plt.title("Average Rain Per State")

plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="2000">

# %%
# Pandas can also plot multiple columns if the DataFrame includes them
multi_plot = rain_df.plot(kind="bar", figsize=(20,5))

# PandasPlot.set_xticklabels() can be used to set the tick labels as well
multi_plot.set_xticklabels(rain_df["State"], rotation=45)

plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="1666.6666666666667">
