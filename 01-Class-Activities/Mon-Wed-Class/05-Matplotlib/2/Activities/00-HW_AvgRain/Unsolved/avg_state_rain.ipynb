# %%
# %matplotlib notebook

# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Load in csv
rain_df = pd.read_csv("../Resources/avg_rain_state.csv")
rain_df
# Out:
#              State  Inches  Milli­metres  Rank
# 0          Alabama    58.3          1480     4
# 1           Alaska    22.5           572    39
# 2          Arizona    13.6           345    47
# 3         Arkansas    50.6          1284     8
# 4       California    22.2           563    40
# 5         Colorado    15.9           405    44
# 6      Connecticut    50.3          1279     9
# 7         Delaware    45.7          1160    16
# 8          Florida    54.5          1385     5
# 9          Georgia    50.7          1287     7
# 10          Hawaii    63.7          1618     1
# 11           Idaho    18.9           481    42
# 12        Illinois    39.2           996    27
# 13         Indiana    41.7          1060    26
# 14            Iowa    34.0           864    31
# 15          Kansas    28.9           733    35
# 16        Kentucky    48.9          1242    12
# 17       Louisiana    60.1          1528     2
# 18           Maine    42.2          1072    23
# 19        Maryland    44.5          1131    18
# 20   Massachusetts    47.7          1211    14
# 21        Michigan    32.8           833    32
# 22       Minnesota    27.3           693    37
# 23     Mississippi    59.0          1499     3
# 24        Missouri    42.2          1071    24
# 25         Montana    15.3           390    45
# 26        Nebraska    23.6           599    38
# 27          Nevada     9.5           241    50
# 28   New Hampshire    43.4          1103    20
# 29      New Jersey    47.1          1196    15
# 30      New Mexico    14.6           370    46
# 31        New York    41.8          1062    25
# 32  North Carolina    50.3          1279     9
# 33    North Dakota    17.8           452    43
# 34            Ohio    39.1           993    28
# 35        Oklahoma    36.5           927    30
# 36          Oregon    27.4           695    36
# 37    Pennsylvania    42.9          1089    21
# 38    Rhode Island    47.9          1218    13
# 39  South Carolina    49.8          1264    11
# 40    South Dakota    20.1           511    41
# 41       Tennessee    54.2          1376     6
# 42           Texas    28.9           734    34
# 43            Utah    12.2           310    49
# 44         Vermont    42.7          1085    22
# 45        Virginia    44.3          1125    19
# 46      Washington    38.4           976    29
# 47   West Virginia    45.2          1147    17
# 48       Wisconsin    32.6           829    33
# 49         Wyoming    12.9           328    48

# %%
# Set x axis and tick locations
x_axis = np.arange(len(rain_df))
x_axis

tick_locations = x_axis

# %%
# Create a list indicating where to write x labels and set figure size to adjust for space
plt.figure(figsize=(15,3))
plt.bar(x_axis, rain_df["Inches"])
plt.xticks(tick_locations, rain_df["State"], rotation="vertical")
# Out:
# <img src="data:image/png;base64,..." width="1500">
# ([<matplotlib.axis.XTick at 0x1f303da0ac8>,
#   <matplotlib.axis.XTick at 0x1f3038fb630>,
#   <matplotlib.axis.XTick at 0x1f3012930f0>,
#   <matplotlib.axis.XTick at 0x1f3051ae400>,
#   <matplotlib.axis.XTick at 0x1f3051ae898>,
#   <matplotlib.axis.XTick at 0x1f3051aedd8>,
#   <matplotlib.axis.XTick at 0x1f3051b8390>,
#   <matplotlib.axis.XTick at 0x1f3051b8908>,
#   <matplotlib.axis.XTick at 0x1f3051b8e80>,
#   <matplotlib.axis.XTick at 0x1f3051c1438>,
#   <matplotlib.axis.XTick at 0x1f3051c19b0>,
#   <matplotlib.axis.XTick at 0x1f3051c1f28>,
#   <matplotlib.axis.XTick at 0x1f3051c64e0>,
#   <matplotlib.axis.XTick at 0x1f3051c1908>,
#   <matplotlib.axis.XTick at 0x1f3051aed30>,
#   <matplotlib.axis.XTick at 0x1f3051c6978>,
#   <matplotlib.axis.XTick at 0x1f3051c6ef0>,
#   <matplotlib.axis.XTick at 0x1f3051cd4a8>,
#   <matplotlib.axis.XTick at 0x1f3051cda20>,
#   <matplotlib.axis.XTick at 0x1f3051cde80>,
#   <matplotlib.axis.XTick at 0x1f3051d6550>,
#   <matplotlib.axis.XTick at 0x1f3051d6ac8>,
#   <matplotlib.axis.XTick at 0x1f3051d6940>,
#   <matplotlib.axis.XTick at 0x1f3051cd978>,
#   <matplotlib.axis.XTick at 0x1f3051b8208>,
#   <matplotlib.axis.XTick at 0x1f3051dc588>,
#   <matplotlib.axis.XTick at 0x1f3051dcb00>,
#   <matplotlib.axis.XTick at 0x1f3051e4128>,
#   <matplotlib.axis.XTick at 0x1f3051e4630>,
#   <matplotlib.axis.XTick at 0x1f3051e4ba8>,
#   <matplotlib.axis.XTick at 0x1f3051eb198>,
#   <matplotlib.axis.XTick at 0x1f3051eb6d8>,
#   <matplotlib.axis.XTick at 0x1f3051e4f98>,
#   <matplotlib.axis.XTick at 0x1f3051c1828>,
#   <matplotlib.axis.XTick at 0x1f3051eb208>,
#   <matplotlib.axis.XTick at 0x1f3051f4160>,
#   <matplotlib.axis.XTick at 0x1f3051f46a0>,
#   <matplotlib.axis.XTick at 0x1f3051f4c18>,
#   <matplotlib.axis.XTick at 0x1f3051f81d0>,
#   <matplotlib.axis.XTick at 0x1f3051f8748>,
#   <matplotlib.axis.XTick at 0x1f3051f8cc0>,
#   <matplotlib.axis.XTick at 0x1f305200278>,
#   <matplotlib.axis.XTick at 0x1f3051f8828>,
#   <matplotlib.axis.XTick at 0x1f3051c6a20>,
#   <matplotlib.axis.XTick at 0x1f3052006a0>,
#   <matplotlib.axis.XTick at 0x1f305200c18>,
#   <matplotlib.axis.XTick at 0x1f3052071d0>,
#   <matplotlib.axis.XTick at 0x1f305207748>,
#   <matplotlib.axis.XTick at 0x1f305207cc0>,
#   <matplotlib.axis.XTick at 0x1f30520f278>],
#  <a list of 50 Text xticklabel objects>)

# %%
# Set x and y limits
plt.xlim(-0.25, len(x_axis))
plt.ylim(0, max(rain_df["Inches"])+10)
# Out:
# (0, 73.7)

# %%
# Set a Title and labels
plt.title("Average Rainfall per State")
plt.xlabel("State")
plt.ylabel("Amount of Rainfall (inches)")
# Out:
# Text(0, 0.5, 'Amount of Rainfall (inches)')

# %%
# Save our graph and show the grap
plt.tight_layout()
plt.savefig('../Images/avg_state_rain.png')
plt.show()
