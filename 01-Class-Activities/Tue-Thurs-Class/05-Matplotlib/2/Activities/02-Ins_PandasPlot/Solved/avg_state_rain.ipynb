# %%
# %matplotlib notebook

# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ### Using MatplotLib to Chart a DataFrame

# %%
# Load in csv
rain_df = pd.read_csv("../Resources/avg_rain_state.csv")
rain_df.head()
# Out:
#         State  Inches  Milli­metres  Rank
# 0     Alabama    58.3          1480     4
# 1      Alaska    22.5           572    39
# 2     Arizona    13.6           345    47
# 3    Arkansas    50.6          1284     8
# 4  California    22.2           563    40

# %%
# Set x axis and tick locations
x_axis = np.arange(len(rain_df))
tick_locations = [value for value in x_axis]

# %%
# Create a list indicating where to write x labels and set figure size to adjust for space
plt.figure(figsize=(20,6))
plt.bar(x_axis, rain_df["Inches"], color='r', alpha=0.5, align="center")
plt.xticks(tick_locations, rain_df["State"], rotation="vertical")
# Out:
# <img src="data:image/png;base64,..." width="2000">
# ([<matplotlib.axis.XTick at 0x284e1be5940>,
#   <matplotlib.axis.XTick at 0x284e307ada0>,
#   <matplotlib.axis.XTick at 0x284e307aa58>,
#   <matplotlib.axis.XTick at 0x284e31521d0>,
#   <matplotlib.axis.XTick at 0x284e3152668>,
#   <matplotlib.axis.XTick at 0x284e3152be0>,
#   <matplotlib.axis.XTick at 0x284e315e198>,
#   <matplotlib.axis.XTick at 0x284e315e710>,
#   <matplotlib.axis.XTick at 0x284e3152240>,
#   <matplotlib.axis.XTick at 0x284e315eda0>,
#   <matplotlib.axis.XTick at 0x284e3166160>,
#   <matplotlib.axis.XTick at 0x284e31666a0>,
#   <matplotlib.axis.XTick at 0x284e3166c18>,
#   <matplotlib.axis.XTick at 0x284e316e1d0>,
#   <matplotlib.axis.XTick at 0x284e316e748>,
#   <matplotlib.axis.XTick at 0x284e316ecc0>,
#   <matplotlib.axis.XTick at 0x284e3176278>,
#   <matplotlib.axis.XTick at 0x284e316e278>,
#   <matplotlib.axis.XTick at 0x284e3166668>,
#   <matplotlib.axis.XTick at 0x284e3176a58>,
#   <matplotlib.axis.XTick at 0x284e3176dd8>,
#   <matplotlib.axis.XTick at 0x284e317d390>,
#   <matplotlib.axis.XTick at 0x284e317d908>,
#   <matplotlib.axis.XTick at 0x284e317de80>,
#   <matplotlib.axis.XTick at 0x284e3183438>,
#   <matplotlib.axis.XTick at 0x284e31839b0>,
#   <matplotlib.axis.XTick at 0x284e3183f28>,
#   <matplotlib.axis.XTick at 0x284e3183908>,
#   <matplotlib.axis.XTick at 0x284e3176d30>,
#   <matplotlib.axis.XTick at 0x284e318a400>,
#   <matplotlib.axis.XTick at 0x284e318a978>,
#   <matplotlib.axis.XTick at 0x284e318aef0>,
#   <matplotlib.axis.XTick at 0x284e31914a8>,
#   <matplotlib.axis.XTick at 0x284e3191a20>,
#   <matplotlib.axis.XTick at 0x284e3191e80>,
#   <matplotlib.axis.XTick at 0x284e3197550>,
#   <matplotlib.axis.XTick at 0x284e3191400>,
#   <matplotlib.axis.XTick at 0x284e318a780>,
#   <matplotlib.axis.XTick at 0x284e3197710>,
#   <matplotlib.axis.XTick at 0x284e3197630>,
#   <matplotlib.axis.XTick at 0x284e319f588>,
#   <matplotlib.axis.XTick at 0x284e319fb00>,
#   <matplotlib.axis.XTick at 0x284e31a6128>,
#   <matplotlib.axis.XTick at 0x284e31a6630>,
#   <matplotlib.axis.XTick at 0x284e31a6ba8>,
#   <matplotlib.axis.XTick at 0x284e31af198>,
#   <matplotlib.axis.XTick at 0x284e31a6a20>,
#   <matplotlib.axis.XTick at 0x284e3197dd8>,
#   <matplotlib.axis.XTick at 0x284e31af5f8>,
#   <matplotlib.axis.XTick at 0x284e31afb70>],
#  <a list of 50 Text xticklabel objects>)

# %%
# Set x and y limits
plt.xlim(-0.75, len(x_axis))
plt.ylim(0, max(rain_df["Inches"])+10)
# Out:
# (0, 73.7)

# %%
# Set a Title and labels
plt.title("Average Rain per State")
plt.xlabel("State")
plt.ylabel("Average Amount of Rainfall in Inches")
# Out:
# Text(0, 0.5, 'Average Amount of Rainfall in Inches')

# %%
# Save our graph and show the grap
plt.tight_layout()
plt.savefig("../Images/avg_state_rain.png")
plt.show()

# %% [markdown]
# ### Using Pandas to Chart a DataFrame

# %%
# Filter the DataFrame down only to those columns to chart
state_and_inches = rain_df[["State","Inches"]]

# Set the index to be "State" so they will be used as labels
state_and_inches = state_and_inches.set_index("State")

state_and_inches.head()
# Out:
#             Inches
# State
# Alabama       58.3
# Alaska        22.5
# Arizona       13.6
# Arkansas      50.6
# California    22.2

# %%
# Use DataFrame.plot() in order to create a bar chart of the data
state_and_inches.plot(kind="bar", figsize=(20,3))

# Set a title for the chart
plt.title("Average Rain Per State")

plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="2000">

# %%
# Pandas can also plot multiple columns if the DataFrame includes them
multi_plot = rain_df.plot(kind="bar", figsize=(20,5))

# PandasPlot.set_xticklabels() can be used to set the tick labels as well
multi_plot.set_xticklabels(rain_df["State"], rotation=45)

plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="2000">
